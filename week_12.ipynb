# %% [markdown]
# <a href="https://colab.research.google.com/github/liamward26/ds1002-vhk7vr/blob/main/week_12.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# ## Pie Chart (3 points)

# %%
# Create a pie chart from raw values

slices = [56, 66, 24, 124, 47]
labels = ["US","UK","MX","CA","JP"]

# %%
import matplotlib.pyplot as plt

plt.pie(slices, labels = labels)
plt.show()

# %% [markdown]
# ## Histogram (3 points)

# %%
# Create a histogram from random data

import matplotlib.pyplot as plt
import numpy as np

n = 430 + np.random.randn(3000)

# %%
plt.hist(n)
# Out:
# (array([  4.,  20., 134., 423., 755., 848., 568., 216.,  29.,   3.]),
#  array([426.14864289, 426.89475781, 427.64087273, 428.38698766,
#         429.13310258, 429.8792175 , 430.62533242, 431.37144734,
#         432.11756226, 432.86367719, 433.60979211]),
#  <BarContainer object of 10 artists>)

# %% [markdown]
# ## Scatterplot with Trendline (3 points)

# %%
# Create a scatterplot with a trendline from two lists of values

import matplotlib.pyplot as plt
import numpy as np
import pandas as pd

num_points = 50
x = 5 + np.arange(num_points) + np.random.randn(num_points)
y = 10 + np.arange(num_points) + 5 * np.random.randn(num_points)

# If you want them combined into a dataframe
df = pd.DataFrame({'x': x, 'y': y})

# %%
z = np.polyfit(x, y, 2)
p = np.poly1d(z)

plt.plot(x, p(x))
plt.scatter(x, y)
