# %% [markdown]
# <a href="https://colab.research.google.com/github/liamward26/ds1002-vhk7vr/blob/main/mock_data_demo.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt

# %matplotlib inline

# %%
#import mockaroo file
mock_data = pd.read_csv("mock_data.csv")

# %%
mock_data.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1000 entries, 0 to 999
# Data columns (total 6 columns):
#  #   Column      Non-Null Count  Dtype
# ---  ------      --------------  -----
#  0   id          1000 non-null   int64
#  1   first_name  1000 non-null   object
#  2   last_name   1000 non-null   object
#  3   email       1000 non-null   object
#  4   gender      1000 non-null   object
#  5   age         1000 non-null   int64
# dtypes: int64(2), object(4)
# memory usage: 47.0+ KB

# %%
mock_data.index
# Out:
# RangeIndex(start=0, stop=1000, step=1)

# %%
#get the head rose (like jazz) / end would be tail
mock_data.head()
# Out:
#    id first_name   last_name                      email  gender  age
# 0   1     Vinnie  McEntagart     vmcentagart0@ameblo.jp    Male   19
# 1   2     Kayley     Adamski           kadamski1@qq.com  Female   46
# 2   3   L;urette  Whalebelly   lwhalebelly2@squidoo.com  Female    4
# 3   4     Rebeca     Willett  rwillett3@ycombinator.com  Female   67
# 4   5    Chryste      Roscoe          croscoe4@1688.com  Female   12

# %%
#one specific entry with .loc
mock_data.loc[87]
# Out:
# id                                     901
# first_name                        Claribel
# last_name                        MacParlan
# email         cmacparlanp0@squarespace.com
# gender                              Female
# age                                     61
# Name: 900, dtype: object

# %%
mock_data.describe()
# Out:
#                 id          age
# count  1000.000000  1000.000000
# mean    500.500000    45.710000
# std     288.819436    25.598421
# min       1.000000     1.000000
# 25%     250.750000    23.000000
# 50%     500.500000    46.000000
# 75%     750.250000    68.000000
# max    1000.000000    90.000000

# %%
# get the columns
mock_data.columns
# Out:
# Index(['id', 'first_name', 'last_name', 'email', 'gender', 'age'], dtype='object')

# %%
# what are the data types
mock_data.dtype

# %%
mock_data = mock_data.rename(columns={"first_name":"fname","last_name":"lname"})

# %%
mock_data.head()
# Out:
#    id     fname       lname                      email  gender  age
# 0   1    Vinnie  McEntagart     vmcentagart0@ameblo.jp    Male   19
# 1   2    Kayley     Adamski           kadamski1@qq.com  Female   46
# 2   3  L;urette  Whalebelly   lwhalebelly2@squidoo.com  Female    4
# 3   4    Rebeca     Willett  rwillett3@ycombinator.com  Female   67
# 4   5   Chryste      Roscoe          croscoe4@1688.com  Female   12

# %%
mock_data[["fname","lname"]]
# Out:
#          fname       lname
# 0       Vinnie  McEntagart
# 1       Kayley     Adamski
# 2     L;urette  Whalebelly
# 3       Rebeca     Willett
# 4      Chryste      Roscoe
# ..         ...         ...
# 995      Regan     Yakubov
# 996  Fleurette      Lesper
# 997     Dallas     Povlsen
# 998     Vasili       Tythe
# 999     Granny     Milmith
#
# [1000 rows x 2 columns]

# %%
pd.value_counts(mock_data["gender"]).plot.bar()
# Out:
# <Axes: >

# %%
mock_data.groupby(["gender"])["age"].mean()
# Out:
# gender
# Agender        40.416667
# Bigender       47.000000
# Female         46.366812
# Genderfluid    51.300000
# Genderqueer    43.142857
# Male           45.074890
# Non-binary     45.857143
# Polygender     47.636364
# Name: age, dtype: float64
